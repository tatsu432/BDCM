# %%
# Import libraries
import numpy as np

import torch
import torch.nn.functional
import torch.utils.data
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline
plt.ioff()  # 対話モードを無効にする

# Warnings
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

from func import normalize
from SCM3 import SCM3

# %%
# Define the structual equation
# X_i = f_i(X_{pa_i}) + U_i

def structural_eq(u, ind, x):
  if ind == 0:
    output = u
  elif ind == 1:
    output = x[0] ** 2 + u
  elif ind == 2:
    output = x[0] + u
  elif ind == 3:
    output = x[0] ** 3 + x[0] + u
  elif ind == 4:
    output = x[2] ** 2 + 0.1 + u
  elif ind == 5:
    output = x[1] * x[3] + u
  elif ind == 6:
    output = x[0] * x[4] + x[5] * x[5] + x[5] * x[0] + u
  return normalize(output)

SCM3(structural_eq=structural_eq, simple_or_complex = "simple")
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
#  50%|█████     | 1/2 [00:01<00:01,  1.54s/it]
# mean of MMD for DCM: 0.0267
# standard deviation of MMD for DCM: 0.00339
# mean of MMD for BDCM: 0.0287
# standard deviation of MMD for BDCM: 0.000204
# 100%|██████████| 2/2 [00:02<00:00,  1.47s/it]
# mean of MMD for DCM: 0.00887
# standard deviation of MMD for DCM: 0.00343
# mean of MMD for BDCM: 0.00711
# standard deviation of MMD for BDCM: 0.00235
# mean of all MMD for DCM: 0.0178
# standard deviation of all MMD for DCM: 0.00952
# mean of all MMD for BDCM: 0.0179
# standard deviation of all MMD for BDCM: 0.0109
